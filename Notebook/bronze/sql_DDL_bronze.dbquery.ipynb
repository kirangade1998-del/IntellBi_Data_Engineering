-- %%
create or replace table intellbi_catalog.intellbi_bronze.rawMonthlySales
(sale_id string, product string, category string, 
quantity string, price string, sale_date string,
 region string,ingest_ts timestamp);



--  describe intellbi_catalog.intellbi_bronze. rawMonthlySales;
 SELECT * FROM intellbi_catalog.intellbi_bronze.rawMonthlySales;
--   drop table intellbi_catalog.intellbi_bronze. dfMonthlySales
--  describe history intellbi_catalog.intellbi_bronze. rawMonthlySales;

drop table intellbi_catalog.intellbi_bronze.rawMonthlySales
