# %%
# %sql
truncate table intellbi_catalog.intellbi_bronze.dfmonthlysales;
truncate table intellbi_catalog.intellbi_silver.dfmonthlysales;
truncate table intellbi_catalog.intellbi_gold.dfmonthlysales;

# %%
# %sql

 select count (*) from intellbi_catalog.intellbi_gold.dfmonthlysales;

# %%
# %sql
select count(*) from intellbi_catalog.intellbi_bronze.dfmonthlysales

# %%
# %sql
select count(*) from intellbi_catalog.intellbi_silver.dfmonthlysales;

# %%
# %sql
select *from intellbi_catalog.intellbi_bronze.dfmonthlysales

# %%
# %sql
select count(*) from intellbi_catalog.intellbi_bronze.dfmonthlysales;
