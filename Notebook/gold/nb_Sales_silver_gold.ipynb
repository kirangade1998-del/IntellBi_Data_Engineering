# %%
# %sql
-- CREaTE TABLE  intellbi_catalog.intellbi_gold.dfMonthlySales
-- AS
-- select * from intellbi_catalog.intellbi_silver.dfMonthlySales where 1=2;

# %%
# %sql
MERGE INTO intellbi_catalog.intellbi_gold.dfMonthlySales
USING intellbi_catalog.intellbi_silver.dfMonthlySales
ON intellbi_catalog.intellbi_gold.dfMonthlySales.sale_id=intellbi_catalog.intellbi_silver.dfMonthlySales.sale_id
WHEN MATCHED THEN UPDATE SET*
WHEN NOT MATCHED THEN INSERT *;

# %%
# %sql
select*from intellbi_catalog.intellbi_gold.dfMonthlySales
