-- %%
create or replace table intellbi_catalog.intellbi_gold.RefinedMonthlySales
(sale_id integer, product string, category string, 
quantity integer, price double, sale_date date,
 region string,
 initial_load_ts timestamp,
 last_modified_ts timestamp);

--  select* from intellbi_catalog.intellbi_gold.RefinedMonthlySales
select* from intellbi_catalog.intellbi_silver.cleansedmonthlysales;
