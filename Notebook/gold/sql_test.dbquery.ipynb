-- %%
-- drop table intellbi_catalog.intellbi_silver.df
truncate table intellbi_catalog.intellbi_bronze.rawMonthlysales;
truncate table intellbi_catalog.intellbi_silver.cleansedmonthlysales;
truncate table intellbi_catalog.intellbi_gold.RefinedMonthlySales;

-------------------------------------------------------------------------
select * from intellbi_catalog.intellbi_bronze.rawMonthlysales;
select * from intellbi_catalog.intellbi_silver.cleansedmonthlysales;
select * from intellbi_catalog.intellbi_gold.RefinedMonthlySales;
