-- %%
create or replace table intellbi_catalog.intellbi_silver.cleansedMonthlySales
(sale_id integer, product string, category string, 
quantity integer, price double, sale_date date,
 region string,ingest_ts timestamp);

 truncate table intellbi_catalog.intellbi_silver.cleansedMonthlySales;

--  describe intellbi_catalog.intellbi_silver. rawMonthlySales;
  SELECT * FROM intellbi_catalog.intellbi_silver.cleansedMonthlysales;
--   drop table intellbi_catalog.intellbi_silver. dfMonthlySales
--  describe history intellbi_catalog.intellbi_silver. rawMonthlySales;
-- drop table intellbi_catalog.intellbi_silver.dfmonthlysales
