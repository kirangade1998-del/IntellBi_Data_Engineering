# %%
# %sql
-- select*from intellbi_catalog.intellbi_bronzE.dfMonthlySales ;

# %%
# %sql
-- select*from intellbi_catalog.intellbi_silver.dfMonthlySales ;

# %%
# %sql


INSERT INTO intellbi_catalog.intellbi_silver.dfmonthlysales
SELECT *
FROM intellbi_catalog.intellbi_bronze.dfmonthlysales

# %%
# %sql

INSERT INTO intellbi_catalog.intellbi_silver.dfmonthlysales
SELECT *
FROM intellbi_catalog.intellbi_bronze.dfmonthlysales
WHERE current_date() > ingest_ts;
